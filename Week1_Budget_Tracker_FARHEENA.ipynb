# %% [markdown]
# <a href="https://colab.research.google.com/github/heenajugoo-270205/farheena_270205/blob/main/Week1_Budget_Tracker_FARHEENA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini Project 01: AI-Powered Budget Tracker
# # ISYS2001 Introduction to Business Programming
#
# **Instructions:**
# 1. Save a copy of this notebook to your Google Drive (File > Save a copy in Drive)
# 2. Rename it to include your name: `Week1_Budget_Tracker_[YourName]`
# 3. Complete all sections and code cells
# 4. Document your AI interactions as you go

# %% [markdown]
# ## Part 1: Environment Setup and First Steps

# %%
# Run this cell to test your environment
print("🎉 Welcome to ISYS2001: Introduction to Business Programming!")
print("📊 Project: Personal Finance Assistant")
print("🤖 Today's Goal: Build a Simple Budget Tracker with AI Help")

# Import datetime to timestamp your work
from datetime import datetime
print(f"\n📅 Worksheet started at: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
# Out:
# 🎉 Welcome to ISYS2001: Introduction to Business Programming!
# 📊 Project: Personal Finance Assistant
# 🤖 Today's Goal: Build a Simple Budget Tracker with AI Help
#
# 📅 Worksheet started at: 2026-02-25 10:30:04

# %% [markdown]
# ## Part 2: Your First AI Prompt
#
# Use an AI assistant (Gemini in Colab, ChatGPT, or GitHub Copilot) to create a program that:
# - Asks the user for their name
# - Asks for their monthly income
# - Prints a personalized welcome message
#
# ### 📝 Document Your AI Prompt Below:

# %%
# TASK: Write your AI prompt as a comment below

#My AI Prompt: Create a program using Python that: Asks the user for their name, Asks for their monthly income, Prints a personalised welcome message


# Paste the AI-generated code below:
# Ask the user for their name
name = input("Please enter your name: ")

# Ask the user for their monthly income
income = float(input("Please enter your monthly income: "))

# Print a personalized welcome message
print(f"\nWelcome, {name}!")
print(f"Your monthly income is ${income:.2f}.")
print("We're glad to have you here!")
# Out:
# Please enter your name: Farheena
# Please enter your monthly income: 25000
#
# Welcome, Farheena!
# Your monthly income is $25000.00.
# We're glad to have you here!

# %% [markdown]
# ### 🔍 Evidence Package Entry #1

# %%
# Evidence Package Documentation
evidence_1 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "I wanted to create a simple input/output Python program to practice AI prompting",
    "ai_tool_used": "ChatGPT",
    "what_worked": "The AI understood my request and provided me with a clear Python program that asked for the name and monthly income, and afterwards it displayed a personalised message.",
    "what_didnt": "I had nothing clarify as the program worked as i inserted it",
    "what_i_learned": "I learned that Python treats user input as text and the function float is required to convert numerical into decimal value."
}

# Display your evidence
print("📋 EVIDENCE PACKAGE #1")
for key, value in evidence_1.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #1
# timestamp: 2026-02-25 10:43:11
# context: I wanted to create a simple input/output Python program to practice AI prompting
# ai_tool_used: ChatGPT
# what_worked: The AI understood my request and provided me with a clear Python program that asked for the name and monthly income, and afterwards it displayed a personalised message.
# what_didnt: I had nothing clarify as the program worked as i inserted it
# what_i_learned: I learned that Python treats user input as text and the function float is required to convert numerical into decimal value.

# %% [markdown]
# ## Part 3: Building the Budget Tracker
#
# Use AI to help you write a program that:
# - Allows users to input their monthly income
# - Allows users to input up to 3 expenses
# - Calculates remaining budget
# - Shows a warning if budget is negative
#
# ### 💡 Pro Tip: Be specific about requirements!

# %%
# TASK: Write your detailed prompt for the budget tracker
"""
My Budget Tracker Prompt:
write a program in Python that:
Allows users to input their monthly income
Allows users to input up to 3 expenses
Calculates remaining budget
Shows a warning if budget is negative
"""
# Out:
# '\nMy Budget Tracker Prompt:\nwrite a program in Python that:\nAllows users to input their monthly income\nAllows users to input up to 3 expenses\nCalculates remaining budget\nShows a warning if budget is negative\n'

# %% [markdown]
# ### Paste and Test Your AI-Generated Budget Tracker

# %%
# AI-GENERATED BUDGET TRACKER CODE
# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Ask for up to 3 expenses
expense1 = float(input("Enter expense 1: "))
expense2 = float(input("Enter expense 2: "))
expense3 = float(input("Enter expense 3: "))

# Calculate total expenses
total_expenses = expense1 + expense2 + expense3

# Calculate remaining budget
remaining_budget = income - total_expenses

# Display results
print("\n--- Budget Summary ---")
print(f"Total expenses: {total_expenses:.2f}")
print(f"Remaining budget: {remaining_budget:.2f}")

# Show warning if budget is negative
if remaining_budget < 0:
    print("⚠️ Warning: Your budget is negative. You are overspending!")
else:
    print("✅ Your budget is within limits.")
# Out:
# Enter your monthly income: 50000
# Enter expense 1: 15000
# Enter expense 2: 15000
# Enter expense 3: 15000
#
# --- Budget Summary ---
# Total expenses: 45000.00
# Remaining budget: 5000.00
# ✅ Your budget is within limits.

# %% [markdown]
# ### 🐛 Debugging and Refinement

# %%
# Document any issues and fixes
issues_found = [
    "Issue 1: Entering text instead of a number caused a ValueError when converting input using float",
    "Fix 1: I ensured that only numerical values are entered.",
    # Add more as needed
]

print("🔧 DEBUGGING NOTES:")
for item in issues_found:
    print(f"- {item}")

# %%
# REFINED VERSION - Your Working Budget Tracker
# REFINED VERSION - Working Budget Tracker

# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Initialize total expenses
total_expenses = 0.0

# Allow user to input up to 3 expenses
for i in range(1, 4):
    expense = float(input(f"Enter expense {i}: "))
    total_expenses += expense

# Calculate remaining budget
remaining_budget = income - total_expenses

# Display budget summary
print("\n--- Budget Summary ---")
print(f"Monthly Income: {income:.2f}")
print(f"Total Expenses: {total_expenses:.2f}")
print(f"Remaining Budget: {remaining_budget:.2f}")

# Show warning if budget is negative
if remaining_budget < 0:
    print("⚠️ Warning: Your budget is negative. You are overspending!")
else:
    print("✅ Your budget is within limits.")
# Out:
# Enter your monthly income: 25000
# Enter expense 1: 12000
# Enter expense 2: 5000
# Enter expense 3: 16000
#
# --- Budget Summary ---
# Monthly Income: 25000.00
# Total Expenses: 33000.00
# Remaining Budget: -8000.00
# ⚠️ Warning: Your budget is negative. You are overspending!

# %% [markdown]
# ## Part 4: Enhancement Challenge
#
# Choose ONE feature to add using AI assistance:
# - 🏷️ Expense categories (food, transport, entertainment)
# - 📊 Show percentage of income spent
# - ✅ Input validation (no negative numbers)
# - 📝 Detailed budget summary with advice

# %%
# Document your enhancement
enhancement_choice = "I chose to add:📊 Show percentage of income spent"
enhancement_prompt = """
using python add a feature that calculates and displays the percentage of monthly income that has been spent.
"""

print(f"🚀 ENHANCEMENT: {enhancement_choice}")
# Out:
# 🚀 ENHANCEMENT: I chose to add:📊 Show percentage of income spent

# %%
# ENHANCED BUDGET TRACKER
# Budget Tracker with Percentage of Income Spent

# Ask for monthly income
income = float(input("Enter your monthly income: "))

# Initialize total expenses
total_expenses = 0.0

# Ask the user to input up to 3 expenses
for i in range(1, 4):
    expense = float(input(f"Enter expense {i}: "))
    total_expenses += expense

# Calculate remaining budget
remaining_budget = income - total_expenses

# Calculate percentage of income spent
percentage_spent = (total_expenses / income) * 100

# Display budget summary
print("\n--- Budget Summary ---")
print(f"Monthly Income: {income:.2f}")
print(f"Total Expenses: {total_expenses:.2f}")
print(f"Remaining Budget: {remaining_budget:.2f}")
print(f"Percentage of Income Spent: {percentage_spent:.2f}%")

# Show warning if budget is negative
if remaining_budget < 0:
    print("⚠️ Warning: Your budget is negative. You are overspending!")
else:
    print("✅ Your budget is within limits.")
# Out:
# Enter your monthly income: 25000
# Enter expense 1: 12000
# Enter expense 2: 5000
# Enter expense 3: 16000
#
# --- Budget Summary ---
# Monthly Income: 25000.00
# Total Expenses: 33000.00
# Remaining Budget: -8000.00
# Percentage of Income Spent: 132.00%
# ⚠️ Warning: Your budget is negative. You are overspending!

# %% [markdown]
# ## Part 5: Reflection and Lab Exit Ticket Preparation

# %%
# Final Evidence Package Summary
evidence_2 = {
    "timestamp": datetime.now().strftime('%Y-%m-%d %H:%M:%S'),
    "context": "Creating the full budget tracker with enhancements, including calculateion of the percentage of monthly income spent.",
    "ai_tool_used": "ChatGPT",
    "prompts_used": 3,
    "iterations_needed": 1,
    "final_reflection": " The AI-assisted programming assisted me in adding specific features in my existing program and refining the program, calculating and displaying the percentage of income spent, understanding the functions used as well as the variable used."
}

print("📋 EVIDENCE PACKAGE #2 (Final)")
for key, value in evidence_2.items():
    print(f"{key}: {value}")
# Out:
# 📋 EVIDENCE PACKAGE #2 (Final)
# timestamp: 2026-02-18 17:37:56
# context: Creating the full budget tracker with enhancements, including calculateion of the percentage of monthly income spent.
# ai_tool_used: ChatGPT
# prompts_used: 1
# iterations_needed: 1
# final_reflection:  The AI-assisted programming assisted me in adding specific features in my existing program and refining the program, calculating and displaying the percentage of income spent, understanding the functions used as well as the variable used.

# %% [markdown]
# ## 🎯 Submission Checklist
#
# Before submitting:
# - ✅ All code cells run without errors
# - ✅ You've documented at least 2 AI interactions
# - ✅ Budget tracker accepts income and 3+ expenses
# - ✅ Completed both Evidence Packages
# - ✅ Attempted the enhancement challenge
# - ✅ Reflected on your AI collaboration experience

# %%
# Generate submission summary
print("="*50)
print("WEEK 1 WORKSHEET COMPLETION SUMMARY")
print("="*50)
print(f"Student Name: JUGOO Bibi Farheena")
print(f"Completion Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("\nCore Features Implemented:")
print("✅ Basic income/expense input")
print("✅ Budget calculation")
print("✅ Warning for negative budget")
print("✅ Enhancement: [Your enhancement]")
print("\nAI Collaboration Stats:")
print(f"- AI tools used: ChatGPT")
print(f"- Number of prompts: 4")
print(f"- Success rate: 100%")
print("\n🎉 Ready for Lab Exit Ticket submission!")
# Out:
# ==================================================
# WEEK 1 WORKSHEET COMPLETION SUMMARY
# ==================================================
# Student Name: JUGOO Bibi Farheena
# Completion Time: 2026-02-18 17:41:40
#
# Core Features Implemented:
# ✅ Basic income/expense input
# ✅ Budget calculation
# ✅ Warning for negative budget
# ✅ Enhancement: [Your enhancement]
#
# AI Collaboration Stats:
# - AI tools used: ChatGPT
# - Number of prompts: 4
# - Success rate: 100%
#
# 🎉 Ready for Lab Exit Ticket submission!

# %% [markdown]
# ## 💭 Final Reflection Questions
#
# **1. What surprised you most about working with AI to generate code?**
#
# I was suprised by how quickly ChatGPT was able to develop Python code. The codes were accurate and clear. The code developed clealry answered the prompts that i inserted and it was meeting my basic requirement that i asked. The enhancement that i asked were also well fulfilled and free from errors.
# This showed me that AI can act as a collaborative partner rather than just a tool for copy-pasting code.
#
# **2. What makes a good prompt vs. a poor prompt?**
#
# A good prompt should be clear, specific and weel structured in order to get the correct output. A poor prompt is vague,unclear and has missing ocntext, which therefore leads to irrelevant code that does not meet the requirement of the question.
#
# **3. How do you see AI tools fitting into your future programming workflow?**
#
# I see AI ass a supportive assistant for my future programming workflow as it will help me to generate codes and learn about the different functions. It will also contribute in identifying errors in future codes that i will be writing. The AI will help me to experiment new ideas and improve both my learning and productivity.
#
# ---
#
# ### 📁 Save and Next Steps:
# 1. File > Save a copy in GitHub (if you haven't already)
# 2. Prepare evidence for next lab session for the Exit Ticket
# 3. Start thinking about Week 2: Variables & Data Types!
